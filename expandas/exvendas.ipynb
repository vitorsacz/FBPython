# %%
# !pip install pandas

# %%
import pandas as pd

# %%
feminicidio_df = pd.read_csv("data/Feminicidio.csv")

# %%
feminicidio_df.sample(5)
# Out:
#     DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO  \
# 224                    DEMACRO     SEC Taboão da Serra
# 460                  DEINTER 4               SEC Bauru
# 56                       DECAP                  8ª SEC
# 500                    DEMACRO  SEC São Bernardo Campo
# 784                 DEINTER 10           SEC Andradina
#
#     MUNICIPIO_CIRCUNSCRICAO               DP_CIRCUNSCRICAO  HD  VITIMAS  \
# 224         Taboão da Serra        002 DP - Taboão da Serra  1        1
# 460                  Agudos                     DM - Agudos  1        1
# 56                São Paulo      054 DP - Cidade Tiradentes  1        1
# 500   São Bernardo do Campo  008 DP - São Bernardo do Campo  1        1
# 784               Andradina              001 DP - Andradina  1        1
#
#      ID_DELEGACIA  MES_ ESTATISTICA  ANO_ESTATISTICA DATAHORA_REGISTRO_BO  \
# 224         30614                12             2017           12/25/2017
# ...

# %%
# !pip install openpyxl

# %%
feminicidio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DEPARTAMENTO_CIRCUNSCRICAO  1060 non-null   object
#  1   SECCIONAL_CIRCUNSCRICAO     1060 non-null   object
#  2   MUNICIPIO_CIRCUNSCRICAO     1060 non-null   object
#  3   DP_CIRCUNSCRICAO            1060 non-null   object
#  4   HD                          1012 non-null   object
#  5   VITIMAS                     1060 non-null   int64
#  6   ID_DELEGACIA                1060 non-null   int64
#  7   MES_ ESTATISTICA            1060 non-null   int64
#  8   ANO_ESTATISTICA             1060 non-null   int64
#  9   DATAHORA_REGISTRO_BO        1060 non-null   object
#  10  NUM_BO                      1060 non-null   object
#  11  ANO_BO                      1060 non-null   int64
#  12  MUNICIPIO_ELABORACAO        1060 non-null   object
# ...
